# %%
import numpy, scipy, sklearn
print("✅ numpy:", numpy.__version__)
print("✅ scipy:", scipy.__version__)
print("✅ scikit-learn:", sklearn.__version__)
# Out:
# ✅ numpy: 2.3.4
# ✅ scipy: 1.16.3
# ✅ scikit-learn: 1.7.2

# %%
from scipy.special import sph_legendre_p
print(sph_legendre_p(1, 0, 0.5))
# Out:
# [0.42878904]
